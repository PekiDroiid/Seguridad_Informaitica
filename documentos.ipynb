# %%
# !pip install pandas

# %%
import pandas 
pandas.read_excel("Libro1.xlsx")
# Out:
#                                            Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                                                 NaN         NaN         NaN
# 1                              tipo de prueba: Manual         NaN         NaN
# 2                                             ID:SMA1         NaN         NaN
# 3                             Entrada o precondicion          NaN  # de pasos
# 4                                       URL de la web         NaN           1
# 5   Correo valido, en el apartado  unicamente pued...         NaN           2
# 6   Contraseña valida, en el apartado no se puede ...         NaN           3
# 7                                 Acceso al dashboard         NaN           4
# 8                                       Cerrar sesión         NaN           5
# 9                                Tester: Luis Carmona         NaN         NaN
# 10                                                NaN         NaN         NaN
# ...

# %%
# !pip install PyPDF2
import PyPDF2

pdf_file = open("Cuadro_comparativo_LACP.pdf", "rb")

pdf_reader = PyPDF2.PdfReader(pdf_file)

for page in pdf_reader.pages:
    text = page.extract_text()
    print(text)

pdf_file.close()
# Out:
# ...
#
# CUADRO COMPARA TIVO
#
#
#
# Luis Alberto Carmona Pech
# 20393103
# SM53
# Desarrollo  Móvil
#
# Partes de Ang ular Descri pción  Características
# MODULO S El modu lo contiene
# dentro de si los
# componentes este es la
# parte principal del
# proyecto  • Dentro de ellos se
# encuentr an los
# componentes
# • Se pueden  tener
# varios módulos  en un
# mismo p royecto
# • Pueden contener
# varios componentes
# dentro de si
#
# COMPONENTES  Los componentes se
# encuentran  dentro de  los
# módulos  estos se
# componen de varios
# archivos dentro de ellos  • Dentro de ellos se
# encuentran archi vos
# css,html,tp  y spec
# • Se pueden tener
# varios componentes
# dentro de un modulo
# • Se pueden exportar  e
# importar los
# componentes de un
# módulo  a otros
# módulos

# %%
# !pip install python-docx

import docx

doc = docx.Document('Cuadro comparativo.docx')

document_text = []

for paragraph in doc.paragraphs:
    document_text.append(paragraph.text)

full_text = '\n'.join(document_text)

print(full_text)
# Out:
# ...
#
# Acabece este pp
